# %% [markdown]
# # Data Preparation
#
# ### Filtering Strategy
#
# **Aggregate Level:** "S". Focuses analysis on individual schools.
# **CharterSchool:** "No" or "N". Excludes charter schools to focus on traditional public high schools.
# **DASS:** "No" or "N". Removes alternative/continuation programs so graduation rates reflect typical comprehensive high schools.
# **ReportingCategory:** "TA". Keeps aggregate totals for each school (not broken down by subgroup) to simplify modeling.

# %%
# import libraries
import importlib
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import subprocess
import sys

from pathlib import Path

# %%
# import other libraries
from helper import (
    rpkl
)

# check if jcds library is installed
package_name = "jcds"

if importlib.util.find_spec(package_name) is None:
    print(f" '{package_name}' not found. Installing from Github... ")
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "https://github.com/junclemente/jcds.git",
        ]
    )
else:
    print(f" '{package_name}' is already installed.")

from jcds import eda as jeda
from jcds import reports as jrep
# Out:
#  'jcds' is already installed.

# %%
# main data folder path
data_folder = Path("../data")
raw_pickle = Path(data_folder / "raw_pickle")

# %% [markdown]
# # California: Department of Education
#
# ## Adjusted Cohort Graduation Rate and Outcome Data (ACGR)
#
# **Adjusted Cohort Graduation Rate and Outcome Data**
# Four-year Adjusted Cohort Graduation Rate (ACGR) and Outcome data reported by race/ethnicity, student group, and gender.
#
# [Data Dictionary: ACGR](https://www.cde.ca.gov/ds/ad/fsacgr.asp)

# %%
df_acgr = rpkl(raw_pickle, "raw_acgr.pkl")

df_acgr.columns.to_list()
# Out:
# ['AcademicYear',
#  'AggregateLevel',
#  'CountyCode',
#  'DistrictCode',
#  'SchoolCode',
#  'CountyName',
#  'DistrictName',
#  'SchoolName',
#  'CharterSchool',
#  'DASS',
#  'ReportingCategory',
#  'CohortStudents',
#  'Regular HS Diploma Graduates (Count)',
#  'Regular HS Diploma Graduates (Rate)',
#  "Met UC/CSU Grad Req's (Count)",
#  "Met UC/CSU Grad Req's (Rate)",
#  'Seal of Biliteracy (Count)',
#  'Seal of Biliteracy (Rate)',
#  'Golden State Seal Merit Diploma (Count)',
#  'Golden State Seal Merit Diploma (Rate',
#  'CHSPE Completer (Count)',
#  'CHSPE Completer (Rate)',
#  'Adult Ed. HS Diploma (Count)',
#  'Adult Ed. HS Diploma (Rate)',
#  'SPED Certificate (Count)',
#  'SPED Certificate (Rate)',
#  'GED Completer (Count)',
#  'GED Completer (Rate)',
#  'Other Transfer (Count)',
#  'Other Transfer (Rate)',
#  'Dropout (Count)',
#  'Dropout (Rate)',
#  'Still Enrolled (Count)',
#  'Still Enrolled (Rate)']

# %%
# select columns
cols_acgr = [
    "AcademicYear",
    "AggregateLevel",
    "CountyCode",
    "DistrictCode",
    "SchoolCode",
    "CountyName",
    "DistrictName",
    "SchoolName",
    "CharterSchool",
    "DASS",
    "ReportingCategory",
    "CohortStudents",  # QA for weighing
    # "Regular HS Diploma Graduates (Count)",
    "Regular HS Diploma Graduates (Rate)",  # target variable
    # "Met UC/CSU Grad Req's (Count)",
    "Met UC/CSU Grad Req's (Rate)",  # academic readiness/intensity feature
    # "Seal of Biliteracy (Count)",
    "Seal of Biliteracy (Rate)",  # ??? language proficiency
    # "Golden State Seal Merit Diploma (Count)",
    # "Golden State Seal Merit Diploma (Rate",
    # "CHSPE Completer (Count)",
    # "CHSPE Completer (Rate)",
    # "Adult Ed. HS Diploma (Count)",
    # "Adult Ed. HS Diploma (Rate)",
    # "SPED Certificate (Count)",
    # "SPED Certificate (Rate)",
    # "GED Completer (Count)",
    # "GED Completer (Rate)",
    # "Other Transfer (Count)",
    # "Other Transfer (Rate)",
    # "Dropout (Count)",
    "Dropout (Rate)",  # secondary target
    # "Still Enrolled (Count)",
    "Still Enrolled (Rate)",  # 5th year senior
]

df_acgr[cols_acgr]
# Out:
#        AcademicYear AggregateLevel CountyCode DistrictCode SchoolCode  \
# 66594       2020-21              S         01        31609    0131755
# 66654       2020-21              S         01        31617    0131763
# 66718       2020-21              S         01        61119    0000001
# 66782       2020-21              S         01        61119    0106401
# 66910       2020-21              S         01        61119    0130229
# ...             ...            ...        ...          ...        ...
# 254262      2020-21              S         58        72736    0000000
# 254314      2020-21              S         58        72736    0000001
# 254426      2020-21              S         58        72736    5830013
# 254630      2020-21              S         58        72736    5835202
# 254766      2020-21              S         58        72769    5838305
#
#        CountyName                                       DistrictName  \
# 66594     Alameda  California School for the Blind (State Special...
# 66654     Alameda  California School for the Deaf-Fremont (State ...
# 66718     Alameda                                    Alameda Unified
# 66782     Alameda                                    Alameda Unified
# 66910     Alameda                                    Alameda Unified
# ...           ...                                                ...
# 254262       Yuba                           Marysville Joint Unified
# 254314       Yuba                           Marysville Joint Unified
# 254426       Yuba                           Marysville Joint Unified
# 254630       Yuba                           Marysville Joint Unified
# 254766       Yuba                               Wheatland Union High
#
#                                       SchoolName CharterSchool DASS  \
# 66594            California School for the Blind           No   No
# 66654     California School for the Deaf-Fremont           No   No
# 66718            Nonpublic, Nonsectarian Schools           No   No
# 66782   Alameda Science and Technology Institute           No   No
# 66910                               Alameda High           No   No
# ...                                          ...           ...  ...
# 254262                           District Office           No   No
# 254314           Nonpublic, Nonsectarian Schools           No   No
# 254426                            Lindhurst High           No   No
# 254630                           Marysville High           No   No
# 254766                      Wheatland Union High           No   No
#
#        ReportingCategory CohortStudents Regular HS Diploma Graduates (Rate)  \
# 66594                 TA             11                                 0.0
# 66654                 TA             38                                63.2
# 66718                 TA              *                                   *
# 66782                 TA             43                               100.0
# 66910                 TA            394                                92.4
# ...                  ...            ...                                 ...
# 254262                TA             69                                56.5
# 254314                TA              *                                   *
# 254426                TA            226                                87.2
# 254630                TA            201                                90.5
# 254766                TA            177                                93.8
#
#        Met UC/CSU Grad Req's (Rate) Seal of Biliteracy (Rate) Dropout (Rate)  \
# 66594                           0.0                       0.0           63.6
# 66654                           0.0                      33.3            2.6
# 66718                             *                         *              *
# 66782                          95.3                       2.3            0.0
# 66910                          73.9                      22.8            2.3
# ...                             ...                       ...            ...
# 254262                          0.0                       0.0           43.5
# 254314                            *                         *              *
# 254426                         36.0                      11.7            6.2
# 254630                         37.4                       1.1            7.0
# 254766                         39.2                       0.0            0.0
#
#        Still Enrolled (Rate)
# 66594                    0.0
# 66654                   28.9
# 66718                      *
# 66782                    0.0
# 66910                    1.0
# ...                      ...
# 254262                   0.0
# 254314                     *
# 254426                   5.8
# 254630                   2.0
# 254766                   5.1
#
# [1502 rows x 17 columns]

# %% [markdown]
# ## Absenteeism
#
# ### Chronic Absenteeism Data
#
# [Data Dictionary: Chronic Absenteeism](https://www.cde.ca.gov/ds/ad/fsabd.asp)

# %%
# load raw dataset and filter
df_chron_abs = rpkl(raw_pickle, "raw_chronic_absent.pkl")
df_chron_abs.columns.to_list()
# Out:
# ['Academic Year',
#  'Aggregate Level',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'Charter School',
#  'Reporting Category',
#  'ChronicAbsenteeismEligibleCumula',
#  'ChronicAbsenteeismCount',
#  'ChronicAbsenteeismRate']

# %%
# select columns
chron_abs_cols = [
    "Academic Year",
    "Aggregate Level",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    # "Charter School",
    # "Reporting Category",
    # "ChronicAbsenteeismEligibleCumula",
    # "ChronicAbsenteeismCount",
    "ChronicAbsenteeismRate",
]

df_chron_abs[chron_abs_cols]
# Out:
#        Academic Year Aggregate Level County Code District Code School Code  \
# 57598        2020-21               S          01         10017     0130419
# 57599        2020-21               S          01         10017     0130401
# 57621        2020-21               S          01         31609     0131755
# 57644        2020-21               S          01         31617     0131763
# 58027        2020-21               S          01         61119     6090013
# ...              ...             ...         ...           ...         ...
# 263006       2020-21               S          58         72751     6056832
# 263008       2020-21               S          58         72751     6056840
# 263062       2020-21               S          58         72769     0123570
# 263063       2020-21               S          58         72769     0133751
# 263064       2020-21               S          58         72769     5838305
#
#        County Name                                      District Name  \
# 57598      Alameda                 Alameda County Office of Education
# 57599      Alameda                 Alameda County Office of Education
# 57621      Alameda  California School for the Blind (State Special...
# 57644      Alameda  California School for the Deaf-Fremont (State ...
# 58027      Alameda                                    Alameda Unified
# ...            ...                                                ...
# 263006        Yuba                                          Wheatland
# 263008        Yuba                                          Wheatland
# 263062        Yuba                               Wheatland Union High
# 263063        Yuba                               Wheatland Union High
# 263064        Yuba                               Wheatland Union High
#
#                                    School Name ChronicAbsenteeismRate
# 57598                 Alameda County Community                   84.4
# 57599       Alameda County Juvenile Hall/Court                   61.7
# 57621          California School for the Blind                    8.8
# 57644   California School for the Deaf-Fremont                   11.6
# 58027                        Edison Elementary                    3.7
# ...                                        ...                    ...
# 263006                    Lone Tree Elementary                   16.7
# 263008                    Wheatland Elementary                   27.1
# 263062            Wheatland Community Day High                    NaN
# 263063                        Edward P. Duplex                    100
# 263064                    Wheatland Union High                   16.9
#
# [8809 rows x 9 columns]

# %% [markdown]
# ### Absenteeism by Reason
#
# [Data Dictionary: Absenteeism by Reason](https://www.cde.ca.gov/ds/ad/fsabr.asp)

# %%
df_abs = rpkl(raw_pickle, "raw_absent_reason.pkl")

df_abs.columns.to_list()
# Out:
# ['Academic Year',
#  'Aggregate Level',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'Charter School',
#  'DASS',
#  'Reporting Category',
#  'Eligible Cumulative Enrollment',
#  'Count of Students with One or More Absences',
#  'Average Days Absent',
#  'Total Days Absent',
#  'Excused Absences (percent)',
#  'Unexcused Absences (percent)',
#  'Out-of-School Suspension Absences (percent)',
#  'Incomplete Independent Study Absences (percent)',
#  'Excused Absences (count)',
#  'Unexcused Absences (count)',
#  'Out-of-School Suspension Absences (count)',
#  'Incomplete Independent Study Absences (count)']

# %%
# select columns
abs_cols = [
    "Academic Year",
    "Aggregate Level",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    "Charter School",
    "DASS",
    "Reporting Category",
    "Eligible Cumulative Enrollment",
    # "Count of Students with One or More Absences",
    # "Average Days Absent",
    # "Total Days Absent",
    # "Excused Absences (percent)",
    "Unexcused Absences (percent)",
    "Out-of-School Suspension Absences (percent)",
    # "Incomplete Independent Study Absences (percent)",
    # "Excused Absences (count)",
    # "Unexcused Absences (count)",
    # "Out-of-School Suspension Absences (count)",
    # "Incomplete Independent Study Absences (count)",
]

df_abs[abs_cols]
# Out:
#        Academic Year Aggregate Level County Code District Code School Code  \
# 583          2021-22               S          01         31609     0131755
# 608          2021-22               S          01         31617     0131763
# 628          2021-22               S          01         61119     0000000
# 647          2021-22               S          01         61119     0106401
# 670          2021-22               S          01         61119     0111765
# ...              ...             ...         ...           ...         ...
# 227659       2021-22               S          58         72751     6056816
# 227682       2021-22               S          58         72751     6056832
# 227706       2021-22               S          58         72751     6056840
# 227743       2021-22               S          58         72769     0000000
# 227808       2021-22               S          58         72769     5838305
#
#        County Name                                      District Name  \
# 583        Alameda  California School for the Blind (State Special...
# 608        Alameda  California School for the Deaf-Fremont (State ...
# 628        Alameda                                    Alameda Unified
# 647        Alameda                                    Alameda Unified
# 670        Alameda                                    Alameda Unified
# ...            ...                                                ...
# 227659        Yuba                                          Wheatland
# 227682        Yuba                                          Wheatland
# 227706        Yuba                                          Wheatland
# 227743        Yuba                               Wheatland Union High
# 227808        Yuba                               Wheatland Union High
#
#                                      School Name Charter School DASS  \
# 583              California School for the Blind            No   No
# 608       California School for the Deaf-Fremont            No   No
# 628                              District Office            No   No
# 647     Alameda Science and Technology Institute            No   No
# 670                      Ruby Bridges Elementary            No   No
# ...                                          ...            ...  ...
# 227659                                Bear River            No   No
# 227682                      Lone Tree Elementary            No   No
# 227706                      Wheatland Elementary            No   No
# 227743                           District Office            No   No
# 227808                      Wheatland Union High            No   No
#
#        Reporting Category Eligible Cumulative Enrollment  \
# 583                    TA                             67
# 608                    TA                            329
# 628                    TA                             22
# 647                    TA                            170
# 670                    TA                            473
# ...                   ...                            ...
# 227659                 TA                            586
# 227682                 TA                            390
# 227706                 TA                            352
# 227743                 TA                              *
# 227808                 TA                           1058
#
#        Unexcused Absences (percent)  \
# 583                            46.9
# 608                            41.8
# 628                               0
# 647                            20.2
# 670                            28.4
# ...                             ...
# 227659                         43.9
# 227682                           29
# 227706                         33.5
# 227743                            *
# 227808                         20.6
#
#        Out-of-School Suspension Absences (percent)
# 583                                              0
# 608                                            1.8
# 628                                              0
# 647                                              0
# 670                                            0.2
# ...                                            ...
# 227659                                         0.2
# 227682                                         0.1
# 227706                                           0
# 227743                                           *
# 227808                                         5.5
#
# [8036 rows x 14 columns]

# %% [markdown]
# ## Public Schools and Districts
#
# [Data Dictionary: Public Schools and Districts](https://www.cde.ca.gov/ds/si/ds/fspubschls.asp)

# %%
df_schooldata = rpkl(raw_pickle, "raw_school_data.pkl")

df_schooldata.columns.to_list()
# Out:
# ['CDSCode',
#  'NCESDist',
#  'NCESSchool',
#  'StatusType',
#  'County',
#  'District',
#  'School',
#  'Street',
#  'StreetAbr',
#  'City',
#  'Zip',
#  'State',
#  'MailStreet',
#  'MailStrAbr',
#  'MailCity',
#  'MailZip',
#  'MailState',
#  'Phone',
#  'Ext',
#  'FaxNumber',
#  'WebSite',
#  'OpenDate',
#  'ClosedDate',
#  'Charter',
#  'CharterNum',
#  'FundingType',
#  'DOC',
#  'DOCType',
#  'SOC',
#  'SOCType',
#  'EdOpsCode',
#  'EdOpsName',
#  'EILCode',
#  'EILName',
#  'GSoffered',
#  'GSserved',
#  'Virtual',
#  'Magnet',
#  'YearRoundYN',
#  'FederalDFCDistrictID',
#  'Latitude',
#  'Longitude',
#  'AdmFName',
#  'AdmLName',
#  'LastUpDate',
#  'Multilingual']

# %%
cols_schooldata = [
    "CDSCode",
    "NCESDist",
    "NCESSchool",
    "StatusType",
    "County",
    "District",
    "School",
    # "Street",
    # "StreetAbr",
    # "City",
    "Zip",
    # "State",
    # "MailStreet",
    # "MailStrAbr",
    # "MailCity",
    # "MailZip",
    # "MailState",
    # "Phone",
    # "Ext",
    # "FaxNumber",
    # "WebSite",
    "OpenDate",
    # "ClosedDate",
    "Charter",
    # "CharterNum",
    # "FundingType",
    # "DOC",
    "DOCType",
    # "SOC",
    "SOCType",
    "EdOpsCode",
    # "EdOpsName",
    "EILCode",
    # "EILName",
    # "GSoffered",
    "GSserved",
    "Virtual",
    "Magnet",
    "YearRoundYN",
    "FederalDFCDistrictID",
    "Latitude",
    "Longitude",
    # "AdmFName",
    # "AdmLName",
    # "LastUpDate",
    "Multilingual",
]

df_schooldata[cols_schooldata]
# Out:
#               CDSCode NCESDist NCESSchool StatusType   County  \
# 2      01100170112607  0691051      10947     Active  Alameda
# 3      01100170114363  0691051      12013     Active  Alameda
# 5      01100170123968  0691051      12844     Active  Alameda
# 6      01100170124172  0691051      12901     Active  Alameda
# 8      01100170126748  0691051      13155     Active  Alameda
# ...               ...      ...        ...        ...      ...
# 18390  58727516056816  0642330      06925     Active     Yuba
# 18392  58727516056832  0642330      06927     Active     Yuba
# 18393  58727516056840  0642330      06928     Active     Yuba
# 18396  58727516118806  0642330      11548     Active     Yuba
# 18403  58727695838305  0642350      06930     Active     Yuba
#
#                                  District  \
# 2      Alameda County Office of Education
# 3      Alameda County Office of Education
# 5      Alameda County Office of Education
# 6      Alameda County Office of Education
# 8      Alameda County Office of Education
# ...                                   ...
# 18390                           Wheatland
# 18392                           Wheatland
# 18393                           Wheatland
# 18396                           Wheatland
# 18403                Wheatland Union High
#
#                                          School         Zip  \
# 2        Envision Academy for Arts & Technology  94612-3355
# 3      American Indian Public Charter School II  94607-4900
# 5       Community School for Creative Education  94606-4903
# 6                               Yu Ming Charter  94607-2477
# 8                      LPS Oakland R & D Campus  94605-4037
# ...                                         ...         ...
# 18390                                Bear River  95692-9286
# 18392                      Lone Tree Elementary       95903
# 18393                      Wheatland Elementary  95692-8215
# 18396                 Wheatland Charter Academy       95903
# 18403                      Wheatland Union High  95692-9798
#
#                   OpenDate Charter  ... EdOpsCode   EILCode GSserved Virtual  \
# 2      2006-08-28 00:00:00       Y  ...      TRAD  ELEMHIGH     6-12       N
# 3      2007-07-01 00:00:00       Y  ...      TRAD      ELEM      K-8       N
# 5      2011-08-22 00:00:00       Y  ...      TRAD      ELEM      K-8       N
# 6      2011-08-09 00:00:00       Y  ...      TRAD      ELEM      K-8       N
# 8      2012-08-21 00:00:00       Y  ...      TRAD        HS     9-12       N
# ...                    ...     ...  ...       ...       ...      ...     ...
# 18390  1980-07-01 00:00:00       N  ...      TRAD  INTMIDJR      4-8       N
# 18392  1980-07-01 00:00:00       N  ...      TRAD      ELEM      K-5       N
# 18393  1980-07-01 00:00:00       N  ...      TRAD      ELEM      K-3       N
# 18396  2001-08-22 00:00:00       Y  ...      TRAD      ELEM      K-5       N
# 18403  1980-07-01 00:00:00       N  ...      TRAD        HS     9-12       N
#
#       Magnet YearRoundYN FederalDFCDistrictID   Latitude   Longitude  \
# 2          N           N              0601614  37.804520  -122.26815
# 3          N           N              0601880  37.800368  -122.26548
# 5          N           N              0601691  37.784648  -122.23863
# 6          N           N              0602013  37.818228  -122.28233
# 8          N           N              0601967  37.759536  -122.16291
# ...      ...         ...                  ...        ...         ...
# 18390      N           N              No Data  39.007843  -121.43617
# 18392      N           N              No Data  39.100027  -121.33614
# 18393      N           N              No Data  39.012487  -121.42900
# 18396      N           N              No Data  39.102475  -121.33536
# 18403      N           N              No Data  38.998968  -121.45497
#
#       Multilingual
# 2                N
# 3                N
# 5                Y
# 6                Y
# 8                N
# ...            ...
# 18390            N
# 18392            N
# 18393            N
# 18396            N
# 18403            N
#
# [9227 rows x 22 columns]

# %% [markdown]
# ## Free or Reduced-Price Meal (Student Poverty)
#
# [Data Dictionary: FRPM ](https://www.cde.ca.gov/ds/ad/fsspfrpm.asp)

# %%
df_frpm = rpkl(raw_pickle, "raw_frpm.pkl")

df_frpm.columns.to_list()
# Out:
# ['Academic Year',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'District Type',
#  'School Type',
#  'Educational Option Type',
#  'NSLP Provision Status',
#  'Charter School (Y/N)',
#  'Charter School Number',
#  'Charter Funding Type',
#  'IRC',
#  'Low Grade',
#  'High Grade',
#  'Enrollment (K-12)',
#  'Free Meal Count (K-12)',
#  'Percent (%) Eligible Free (K-12)',
#  'FRPM Count (K-12)',
#  'Percent (%) Eligible FRPM (K-12)',
#  'Enrollment (Ages 5-17)',
#  'Free Meal Count (Ages 5-17)',
#  'Percent (%) Eligible Free (Ages 5-17)',
#  'FRPM Count (Ages 5-17)',
#  'Percent (%) Eligible FRPM (Ages 5-17)',
#  'CALPADS Fall 1 Certification Status']

# %%
cols_frpm = [
    "Academic Year",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    "District Type",
    "School Type",
    "Educational Option Type",
    # "NSLP Provision Status",
    "Charter School (Y/N)",
    # "Charter School Number",
    # "Charter Funding Type",
    "IRC",
    # "Low Grade",
    # "High Grade",
    "Enrollment (K-12)",
    # "Free Meal Count (K-12)",
    "Percent (%) Eligible Free (K-12)",
    "FRPM Count (K-12)",
    "Percent (%) Eligible FRPM (K-12)",
    # "Enrollment (Ages 5-17)",
    # "Free Meal Count (Ages 5-17)",
    # "Percent (%) Eligible Free (Ages 5-17)",
    # "FRPM Count (Ages 5-17)",
    # "Percent (%) Eligible FRPM (Ages 5-17)",
    "CALPADS Fall 1 Certification Status",
]

df_frpm[cols_frpm]
# Out:
#       Academic Year  County Code  District Code  School Code County Name  \
# 0         2021-2022            1          10017       130419     Alameda
# 1         2021-2022            1          10017       130401     Alameda
# 14        2021-2022            1          31609       131755     Alameda
# 15        2021-2022            1          31617       131763     Alameda
# 17        2021-2022            1          61119       130229     Alameda
# ...             ...          ...            ...          ...         ...
# 10550     2021-2022           58          72751      6056832        Yuba
# 10552     2021-2022           58          72751      6056840        Yuba
# 10554     2021-2022           58          72769       133751        Yuba
# 10556     2021-2022           58          72769       123570        Yuba
# 10557     2021-2022           58          72769      5838305        Yuba
#
#                                            District Name  \
# 0                     Alameda County Office of Education
# 1                     Alameda County Office of Education
# 14     California School for the Blind (State Special...
# 15     California School for the Deaf-Fremont (State ...
# 17                                       Alameda Unified
# ...                                                  ...
# 10550                                          Wheatland
# 10552                                          Wheatland
# 10554                               Wheatland Union High
# 10556                               Wheatland Union High
# 10557                               Wheatland Union High
#
#                                   School Name  \
# 0                    Alameda County Community
# 1          Alameda County Juvenile Hall/Court
# 14            California School for the Blind
# 15     California School for the Deaf-Fremont
# 17                               Alameda High
# ...                                       ...
# 10550                    Lone Tree Elementary
# 10552                    Wheatland Elementary
# 10554                        Edward P. Duplex
# 10556            Wheatland Community Day High
# 10557                    Wheatland Union High
#
#                           District Type                     School Type  \
# 0      County Office of Education (COE)                County Community
# 1      County Office of Education (COE)          Juvenile Court Schools
# 14                State Special Schools           State Special Schools
# 15                State Special Schools           State Special Schools
# 17              Unified School District           High Schools (Public)
# ...                                 ...                             ...
# 10550        Elementary School District     Elementary Schools (Public)
# 10552        Elementary School District     Elementary Schools (Public)
# 10554              High School District       Continuation High Schools
# 10556              High School District  District Community Day Schools
# 10557              High School District           High Schools (Public)
#
#        Educational Option Type Charter School (Y/N) IRC  Enrollment (K-12)  \
# 0      County Community School                    N   N                 57
# 1        Juvenile Court School                    N   N                 64
# 14        State Special School                    N   N                 62
# 15        State Special School                    N   N                318
# 17                 Traditional                    N   N               1808
# ...                        ...                  ...  ..                ...
# 10550              Traditional                    N   N                351
# 10552              Traditional                    N   N                340
# 10554      Continuation School                    N   N                 45
# 10556     Community Day School                    N   N                  5
# 10557              Traditional                    N   N               1012
#
#        Percent (%) Eligible Free (K-12)  FRPM Count (K-12)  \
# 0                              0.789474                 47
# 1                              1.000000                 64
# 14                             1.000000                 62
# 15                             1.000000                318
# 17                             0.172013                327
# ...                                 ...                ...
# 10550                          0.193732                119
# 10552                          0.523529                189
# 10554                          0.711111                 45
# 10556                          0.600000                  4
# 10557                          0.428854                750
#
#        Percent (%) Eligible FRPM (K-12) CALPADS Fall 1 Certification Status
# 0                              0.824561                                   Y
# 1                              1.000000                                   Y
# 14                             1.000000                                   Y
# 15                             1.000000                                   Y
# 17                             0.180863                                   Y
# ...                                 ...                                 ...
# 10550                          0.339031                                   Y
# 10552                          0.555882                                   Y
# 10554                          1.000000                                   Y
# 10556                          0.800000                                   Y
# 10557                          0.741107                                   Y
#
# [8705 rows x 17 columns]

# %% [markdown]
# ## CBEDS Data about Schools & Districts
#
# [Data Dictionary: CBEDS](https://www.cde.ca.gov/ds/ad/fscbedsorab19.asp)

# %%
df_cbeds = rpkl(raw_pickle, "raw_cbeds.pkl")

df_cbeds.columns.to_list()
# Out:
# ['Cdscode',
#  'CountyName',
#  'DistrictName',
#  'SchoolName',
#  'Description',
#  'Level',
#  'Section',
#  'RowNumber',
#  'Value',
#  'Year']

# %%
col_cbeds = [
    "Cdscode",
    "CountyName",
    "DistrictName",
    "SchoolName",
    #  'Description',
    "Level",
    #  'Section',
    #  'RowNumber',
    "Value",
    "Year",
]

df_cbeds[col_cbeds]
# Out:
#               Cdscode CountyName                        DistrictName  \
# 18     01100170112607    Alameda  Alameda County Office of Education
# 19     01100170112607    Alameda  Alameda County Office of Education
# 20     01100170112607    Alameda  Alameda County Office of Education
# 21     01100170112607    Alameda  Alameda County Office of Education
# 22     01100170112607    Alameda  Alameda County Office of Education
# ...               ...        ...                                 ...
# 58706  58727695838305       Yuba                Wheatland Union High
# 58707  58727695838305       Yuba                Wheatland Union High
# 58708  58727695838305       Yuba                Wheatland Union High
# 58709  58727695838305       Yuba                Wheatland Union High
# 58710  58727695838305       Yuba                Wheatland Union High
#
#                                    SchoolName Level     Value  Year
# 18     Envision Academy for Arts & Technology     S      True  2122
# 19     Envision Academy for Arts & Technology     S      True  2122
# 20     Envision Academy for Arts & Technology     S         0  2122
# 21     Envision Academy for Arts & Technology     S         0  2122
# 22     Envision Academy for Arts & Technology     S      True  2122
# ...                                       ...   ...       ...   ...
# 58706                    Wheatland Union High     S      True  2122
# 58707                    Wheatland Union High     S      True  2122
# 58708                    Wheatland Union High     S      True  2122
# 58709                    Wheatland Union High     S  20210811  2122
# 58710                    Wheatland Union High     S  20220602  2122
#
# [52459 rows x 7 columns]

# %% [markdown]
# ## Staff Data Files
#
# ### Student / Staff Ratio
#
# [Data Dictionary: Student-Staff Ratio](https://www.cde.ca.gov/ds/ad/fsstrat.asp)

# %%
df_ss_ratio = rpkl(raw_pickle, "raw_student_staff_ratio.pkl")

df_ss_ratio.columns.to_list()
# Out:
# ['Academic Year',
#  'Aggregate Level',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'Charter School',
#  'DASS',
#  'School Grade Span',
#  'TOTAL_ENR_N',
#  'TCH_FTE_N',
#  'ADM_FTE_N',
#  'PSV_FTE_N',
#  'OTH_FTE_N',
#  'STU_TCH_RATIO',
#  'STU_ADM_RATIO',
#  'STU_PSV_RATIO',
#  'STU_OTH_RATIO']

# %%
cols_ss_ratio = [
    "Academic Year",
    "Aggregate Level",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    "Charter School",
    "DASS",
    "School Grade Span",
    # "TOTAL_ENR_N",
    # "TCH_FTE_N",
    # "ADM_FTE_N",
    # "PSV_FTE_N",
    # "OTH_FTE_N",
    "STU_TCH_RATIO",  # student / teacher ratio
    "STU_ADM_RATIO",  # student / admin ratio
    "STU_PSV_RATIO",  # student / counselor ratio
    # "STU_OTH_RATIO",
]

df_ss_ratio[cols_ss_ratio]
# Out:
#       Academic Year Aggregate Level County Code District Code School Code  \
# 556         2021-22               S          01         10017     0000000
# 571         2021-22               S          01         31609     0131755
# 572         2021-22               S          01         31617     0000000
# 573         2021-22               S          01         31617     0131763
# 574         2021-22               S          01         61119     0000000
# ...             ...             ...         ...           ...         ...
# 30235       2021-22               S          58         72751     6056816
# 30236       2021-22               S          58         72751     6056832
# 30237       2021-22               S          58         72751     6056840
# 30239       2021-22               S          58         72769     0000000
# 30242       2021-22               S          58         72769     5838305
#
#       County Name                                      District Name  \
# 556       Alameda                 Alameda County Office of Education
# 571       Alameda  California School for the Blind (State Special...
# 572       Alameda  California School for the Deaf-Fremont (State ...
# 573       Alameda  California School for the Deaf-Fremont (State ...
# 574       Alameda                                    Alameda Unified
# ...           ...                                                ...
# 30235        Yuba                                          Wheatland
# 30236        Yuba                                          Wheatland
# 30237        Yuba                                          Wheatland
# 30239        Yuba                               Wheatland Union High
# 30242        Yuba                               Wheatland Union High
#
#                                   School Name Charter School DASS  \
# 556                           District Office              N    N
# 571           California School for the Blind              N    N
# 572                           District Office              N    N
# 573    California School for the Deaf-Fremont              N    N
# 574                           District Office              N    N
# ...                                       ...            ...  ...
# 30235                              Bear River              N    N
# 30236                    Lone Tree Elementary              N    N
# 30237                    Wheatland Elementary              N    N
# 30239                         District Office              N    N
# 30242                    Wheatland Union High              N    N
#
#       School Grade Span STU_TCH_RATIO STU_ADM_RATIO STU_PSV_RATIO
# 556              GS_K12             *             *             *
# 571              GS_K12           4.8          12.4           3.9
# 572              GS_K12             *             *             *
# 573              GS_K12           4.4          40.3           159
# 574              GS_K12             *             *             *
# ...                 ...           ...           ...           ...
# 30235            GS_K12          18.9           284         180.3
# 30236             GS_K6          20.6             *         175.5
# 30237             GS_K6            20           340         123.6
# 30239            GS_K12             *             3             *
# 30242            GS_912          21.8         562.2         190.9
#
# [8772 rows x 14 columns]

# %% [markdown]
# ### Staff Education
#
# [Data Dictionary: Staff Education](https://www.cde.ca.gov/ds/ad/fssted.asp)

# %%
df_staff_ed = rpkl(raw_pickle, "raw_staff_edu.pkl")

df_staff_ed.columns.to_list()
# Out:
# ['Academic Year',
#  'Aggregate Level',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'Charter School',
#  'DASS',
#  'Staff Type',
#  'School Grade Span',
#  'Staff Gender',
#  'Total Staff Count',
#  'Associate',
#  'Baccalaureate',
#  'Baccalaureate Plus',
#  'Master',
#  'Master Plus',
#  'Doctorate',
#  'Special (Juris Doctor)',
#  'None']

# %%
cols_staff_ed = [
    "Academic Year",
    "Aggregate Level",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    "Charter School",
    "DASS",
    "Staff Type",
    "School Grade Span",
    # "Staff Gender",
    "Total Staff Count",
    "Associate",
    "Baccalaureate",
    "Baccalaureate Plus",
    "Master",
    "Master Plus",
    "Doctorate",
    "Special (Juris Doctor)",
    "None",
]

df_staff_ed[cols_staff_ed]
# Out:
#        Academic Year Aggregate Level County Code District Code School Code  \
# 7395         2021-22               S          01         10017     0000000
# 7396         2021-22               S          01         10017     0000000
# 7397         2021-22               S          01         10017     0000000
# 7398         2021-22               S          01         10017     0000000
# 7399         2021-22               S          01         10017     0000000
# ...              ...             ...         ...           ...         ...
# 360896       2021-22               S          58         10587     0000000
# 360897       2021-22               S          58         10587     0000000
# 360898       2021-22               S          58         10587     0000000
# 360899       2021-22               S          58         10587     0000000
# 360900       2021-22               S          58         10587     0000000
#
#        County Name                       District Name      School Name  \
# 7395       Alameda  Alameda County Office of Education  District Office
# 7396       Alameda  Alameda County Office of Education  District Office
# 7397       Alameda  Alameda County Office of Education  District Office
# 7398       Alameda  Alameda County Office of Education  District Office
# 7399       Alameda  Alameda County Office of Education  District Office
# ...            ...                                 ...              ...
# 360896        Yuba     Yuba County Office of Education  District Office
# 360897        Yuba     Yuba County Office of Education  District Office
# 360898        Yuba     Yuba County Office of Education  District Office
# 360899        Yuba     Yuba County Office of Education  District Office
# 360900        Yuba     Yuba County Office of Education  District Office
#
#        Charter School DASS  ... School Grade Span Total Staff Count Associate  \
# 7395                N    N  ...            GS_K12                 5         0
# 7396                N    N  ...            GS_K12                 5         0
# 7397                N    N  ...            GS_K12                 6         0
# 7398                N    N  ...            GS_K12                 6         0
# 7399                N    N  ...            GS_K12                 1         0
# ...               ...  ...  ...               ...               ...       ...
# 360896              N    N  ...            GS_K12                11         0
# 360897              N    N  ...            GS_K12                 9         0
# 360898              N    N  ...            GS_K12                 2         0
# 360899              N    N  ...            GS_K12                 1         0
# 360900              N    N  ...            GS_K12                 1         0
#
#        Baccalaureate Baccalaureate Plus Master Master Plus Doctorate  \
# 7395               0                  0      0           4         1
# 7396               0                  0      0           4         1
# 7397               0                  0      0           5         1
# 7398               0                  0      0           5         1
# 7399               0                  0      0           1         0
# ...              ...                ...    ...         ...       ...
# 360896             2                  1      7           0         1
# 360897             2                  1      6           0         0
# 360898             0                  0      1           0         1
# 360899             0                  1      0           0         0
# 360900             0                  1      0           0         0
#
#        Special (Juris Doctor) None
# 7395                        0    0
# 7396                        0    0
# 7397                        0    0
# 7398                        0    0
# 7399                        0    0
# ...                       ...  ...
# 360896                      0    0
# 360897                      0    0
# 360898                      0    0
# 360899                      0    0
# 360900                      0    0
#
# [99212 rows x 21 columns]

# %% [markdown]
# ### Staff Experience
#
# [Data Dictionary: Staff Experience](https://www.cde.ca.gov/ds/ad/fsstex.asp)

# %%
df_staff_xp = rpkl(raw_pickle, "raw_staff_exp.pkl")

df_staff_xp.columns.to_list()
# Out:
# ['Academic Year',
#  'Aggregate Level',
#  'County Code',
#  'District Code',
#  'School Code',
#  'County Name',
#  'District Name',
#  'School Name',
#  'Charter School',
#  'DASS',
#  'Staff Type',
#  'School Grade Span',
#  'Staff Gender',
#  'Total Staff Count',
#  'Average Total Years Experience',
#  'Average District Years Experience',
#  'Experienced',
#  'Inexperienced',
#  'First Year',
#  'Second Year']

# %%
cols_staff_xp = [
    "Academic Year",
    "Aggregate Level",
    "County Code",
    "District Code",
    "School Code",
    "County Name",
    "District Name",
    "School Name",
    "Charter School",
    "DASS",
    "Staff Type",
    "School Grade Span",
    # "Staff Gender",
    "Total Staff Count",
    "Average Total Years Experience",
    "Average District Years Experience",
    "Experienced",  # 2+ years experience
    "Inexperienced",  # <2 years experience
    "First Year",  # No of staff in 1st year
    "Second Year",  # No of staff in 2nd year
]

df_staff_xp[cols_staff_xp]
# Out:
#        Academic Year Aggregate Level County Code District Code School Code  \
# 7395         2021-22               S          01         10017     0000000
# 7396         2021-22               S          01         10017     0000000
# 7397         2021-22               S          01         10017     0000000
# 7398         2021-22               S          01         10017     0000000
# 7399         2021-22               S          01         10017     0000000
# ...              ...             ...         ...           ...         ...
# 360896       2021-22               S          58         10587     0000000
# 360897       2021-22               S          58         10587     0000000
# 360898       2021-22               S          58         10587     0000000
# 360899       2021-22               S          58         10587     0000000
# 360900       2021-22               S          58         10587     0000000
#
#        County Name                       District Name      School Name  \
# 7395       Alameda  Alameda County Office of Education  District Office
# 7396       Alameda  Alameda County Office of Education  District Office
# 7397       Alameda  Alameda County Office of Education  District Office
# 7398       Alameda  Alameda County Office of Education  District Office
# 7399       Alameda  Alameda County Office of Education  District Office
# ...            ...                                 ...              ...
# 360896        Yuba     Yuba County Office of Education  District Office
# 360897        Yuba     Yuba County Office of Education  District Office
# 360898        Yuba     Yuba County Office of Education  District Office
# 360899        Yuba     Yuba County Office of Education  District Office
# 360900        Yuba     Yuba County Office of Education  District Office
#
#        Charter School DASS Staff Type School Grade Span Total Staff Count  \
# 7395                N    N        ADM            GS_K12                 5
# 7396                N    N        ADM            GS_K12                 5
# 7397                N    N        ALL            GS_K12                 6
# 7398                N    N        ALL            GS_K12                 6
# 7399                N    N        OTH            GS_K12                 1
# ...               ...  ...        ...               ...               ...
# 360896              N    N        ALL            GS_K12                11
# 360897              N    N        ALL            GS_K12                 9
# 360898              N    N        ALL            GS_K12                 2
# 360899              N    N        OTH            GS_K12                 1
# 360900              N    N        OTH            GS_K12                 1
#
#        Average Total Years Experience Average District Years Experience  \
# 7395                             20.6                               9.2
# 7396                             20.6                               9.2
# 7397                             20.0                              10.2
# 7398                             20.0                              10.2
# 7399                             17.0                              15.0
# ...                               ...                               ...
# 360896                           21.6                              14.6
# 360897                           22.8                              16.0
# 360898                           16.5                               8.5
# 360899                           16.0                              15.0
# 360900                           16.0                              15.0
#
#        Experienced Inexperienced First Year Second Year
# 7395             5             0          0           0
# 7396             5             0          0           0
# 7397             6             0          0           0
# 7398             6             0          0           0
# 7399             1             0          0           0
# ...            ...           ...        ...         ...
# 360896          11             0          0           0
# 360897           9             0          0           0
# 360898           2             0          0           0
# 360899           1             0          0           0
# 360900           1             0          0           0
#
# [99212 rows x 19 columns]

# %% [markdown]
# ## Enrollment by School
#
# [Data Dictionary: Enrollment by School](https://www.cde.ca.gov/ds/ad/fsenrps.asp)

# %%
df_enroll = rpkl(raw_pickle, "raw_school_enroll.pkl")

df_enroll.columns.to_list()
# Out:
# ['ACADEMIC_YEAR',
#  'CDS_CODE',
#  'COUNTY',
#  'DISTRICT',
#  'SCHOOL',
#  'ENR_TYPE',
#  'RACE_ETHNICITY',
#  'GENDER',
#  'GR_KN',
#  'GR_1',
#  'GR_2',
#  'GR_3',
#  'GR_4',
#  'GR_5',
#  'GR_6',
#  'GR_7',
#  'GR_8',
#  'UNGR_ELM',
#  'GR_9',
#  'GR_10',
#  'GR_11',
#  'GR_12',
#  'UNGR_SEC',
#  'ENR_TOTAL',
#  'ADULT']

# %%
cols_enroll = [
    "ACADEMIC_YEAR",
    "CDS_CODE",
    "COUNTY",
    "DISTRICT",
    "SCHOOL",
    "ENR_TYPE",
    "RACE_ETHNICITY",
    "GENDER",
    # "GR_KN",
    # "GR_1",
    # "GR_2",
    # "GR_3",
    # "GR_4",
    # "GR_5",
    # "GR_6",
    # "GR_7",
    # "GR_8",
    # "UNGR_ELM",
    "GR_9",
    "GR_10",
    "GR_11",
    "GR_12",
    "UNGR_SEC",
    "ENR_TOTAL",
    # "ADULT",
]

df_enroll[cols_enroll]
# Out:
#        ACADEMIC_YEAR        CDS_CODE   COUNTY  \
# 15           2020-21  01100170112607  ALAMEDA
# 16           2020-21  01100170112607  ALAMEDA
# 17           2020-21  01100170112607  ALAMEDA
# 18           2020-21  01100170112607  ALAMEDA
# 19           2020-21  01100170112607  ALAMEDA
# ...              ...             ...      ...
# 793375       2022-23  58727695838305     YUBA
# 793376       2022-23  58727695838305     YUBA
# 793377       2022-23  58727695838305     YUBA
# 793378       2022-23  58727695838305     YUBA
# 793379       2022-23  58727695838305     YUBA
#
#                                   DISTRICT  \
# 15      Alameda County Office of Education
# 16      Alameda County Office of Education
# 17      Alameda County Office of Education
# 18      Alameda County Office of Education
# 19      Alameda County Office of Education
# ...                                    ...
# 793375                Wheatland Union High
# 793376                Wheatland Union High
# 793377                Wheatland Union High
# 793378                Wheatland Union High
# 793379                Wheatland Union High
#
#                                         SCHOOL ENR_TYPE RACE_ETHNICITY GENDER  \
# 15      Envision Academy for Arts & Technology        P              0      F
# 16      Envision Academy for Arts & Technology        P              0      M
# 17      Envision Academy for Arts & Technology        P              1      F
# 18      Envision Academy for Arts & Technology        P              2      F
# 19      Envision Academy for Arts & Technology        P              2      M
# ...                                        ...      ...            ...    ...
# 793375                    Wheatland Union High        P              7      F
# 793376                    Wheatland Union High        P              7      M
# 793377                    Wheatland Union High        P              7      X
# 793378                    Wheatland Union High        P              9      F
# 793379                    Wheatland Union High        P              9      M
#
#        GR_9 GR_10 GR_11 GR_12 UNGR_SEC ENR_TOTAL
# 15        1     0     1     0        0         6
# 16        0     1     1     0        0         3
# 17        1     1     0     1        0         3
# 18        1     0     0     0        0         1
# 19        0     1     0     0        0         1
# ...     ...   ...   ...   ...      ...       ...
# 793375   35    54    60    43        0       192
# 793376   61    67    61    63        0       252
# 793377    0     0     1     0        0         1
# 793378   16    10    14    12        0        52
# 793379   14    19    14    12        0        59
#
# [396675 rows x 14 columns]

# %% [markdown]
# # Ca DOE School Climate, Health, and Learning Surveys
#
# ## Perception of Safety by Grade Level

# %%
df_safety = rpkl(raw_pickle, "raw_safety_percept_grade.pkl")

df_safety.columns.to_list()
# Out:
# ['geography',
#  'geo_type',
#  'grade',
#  'very_safe_pct',
#  'safe_pct',
#  'neither_pct',
#  'unsafe_pct',
#  'very_unsafe_pct',
#  'years',
#  'level_of_safety_filter']

# %%
cols_safety = ['geography',
 'geo_type',
 'grade',
 'very_safe_pct',
 'safe_pct',
 'neither_pct',
 'unsafe_pct',
 'very_unsafe_pct',
 'years',
 'level_of_safety_filter']

df_safety[cols_safety]
# Out:
#           geography geo_type  grade  very_safe_pct  safe_pct  neither_pct  \
# 0        California    State      9          0.128     0.420        0.364
# 1        California    State     11          0.134     0.403        0.373
# 2    Alameda County   County      9          0.132     0.459        0.341
# 3    Alameda County   County     11          0.145     0.423        0.351
# 4     Amador County   County      9          0.153     0.403        0.374
# ..              ...      ...    ...            ...       ...          ...
# 109  Ventura County   County     11          0.162     0.420        0.335
# 110     Yolo County   County      9          0.139     0.424        0.371
# 111     Yolo County   County     11          0.162     0.437        0.342
# 112     Yuba County   County      9          0.075     0.415        0.359
# 113     Yuba County   County     11          0.092     0.365        0.402
#
#      unsafe_pct  very_unsafe_pct      years level_of_safety_filter
# 0         0.053            0.035  2017-2019                    All
# 1         0.055            0.036  2017-2019                    All
# 2         0.044            0.023  2017-2019                    All
# 3         0.051            0.029  2017-2019                    All
# 4         0.048            0.021  2017-2019                    All
# ..          ...              ...        ...                    ...
# 109       0.050            0.033  2017-2019                    All
# 110       0.043            0.023  2017-2019                    All
# 111       0.034            0.025  2017-2019                    All
# 112       0.097            0.055  2017-2019                    All
# 113       0.079            0.061  2017-2019                    All
#
# [114 rows x 10 columns]

# %% [markdown]
# ## Perception of Safety by School Connectedness

# %%
df_connected = rpkl(raw_pickle, "raw_safety_connect.pkl")

df_connected.columns.to_list()
# Out:
# ['Geography',
#  'Connectedness',
#  'Very Safe',
#  'Safe',
#  'Neither Safe nor Unsafe',
#  'Unsafe',
#  'Very Unsafe',
#  'Safety_Positive']

# %%
cols_connected = ['Geography',
 'Connectedness',
 'Very Safe',
 'Safe',
 'Neither Safe nor Unsafe',
 'Unsafe',
 'Very Unsafe',
 'Safety_Positive']

df_connected[cols_connected]
# Out:
#           Geography Connectedness  Very Safe   Safe  Neither Safe nor Unsafe  \
# 0        California          High      0.268  0.559                    0.157
# 1        California        Medium      0.052  0.334                    0.520
# 2        California           Low      0.069  0.111                    0.428
# 3    Alameda County          High      0.268  0.582                    0.138
# 4    Alameda County        Medium      0.060  0.370                    0.494
# ..              ...           ...        ...    ...                      ...
# 172     Yolo County        Medium      0.064  0.385                    0.475
# 173     Yolo County           Low      0.083  0.136                    0.456
# 174     Yuba County          High      0.234  0.584                    0.160
# 175     Yuba County        Medium      0.036  0.331                    0.498
# 176     Yuba County           Low      0.033  0.102                    0.438
#
#      Unsafe  Very Unsafe  Safety_Positive
# 0     0.011        0.005            0.827
# 1     0.065        0.028            0.386
# 2     0.196        0.196            0.180
# 3     0.009        0.004            0.850
# 4     0.057        0.020            0.430
# ..      ...          ...              ...
# 172   0.053        0.022            0.449
# 173   0.163        0.162            0.219
# 174   0.015        0.007            0.818
# 175   0.086        0.049            0.367
# 176   0.240        0.186            0.135
#
# [177 rows x 8 columns]
